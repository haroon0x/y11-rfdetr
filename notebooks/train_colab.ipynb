# %% [markdown]
# # Long-Range Person Detection Training (YOLOv11m)
#
# This notebook is designed to run the training pipeline on Google Colab.

# %%
# 1. Clone the Repository (Replace with your actual repo URL if needed)
# If you are uploading files manually, skip this step.
# !git clone https://github.com/yourusername/y11-rfdetr.git
# %cd y11-rfdetr

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt
# !pip install ultralytics

# %%
# 3. Verify Environment
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device: {torch.cuda.get_device_name(0)}")

# %%
# 4. Run Training Pipeline (VisDrone)
# This will automatically download VisDrone and start training
# !python scripts/train_pipeline.py

# %%
# 5. (Optional) Run Smoke Test first to verify setup
# !python scripts/train_pipeline.py --smoke-test

# %%
# 6. Zip and Download Results
# !zip -r runs.zip long_range_pipeline/
from google.colab import files
files.download('runs.zip')
