# %% [markdown]
# # Long-Range Person Detection Training (YOLOv11)
#
# This notebook is designed to run the training pipeline on Google Colab.
# It supports training different model sizes (e.g., YOLOv11n, YOLOv11m).

# %%
# 1. Clone the Repository (Replace with your actual repo URL if needed)
# If you are uploading files manually, skip this step.
# !git clone https://github.com/yourusername/y11-rfdetr.git
# %cd y11-rfdetr

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt
# !pip install ultralytics

# %%
# 3. Verify Environment
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device: {torch.cuda.get_device_name(0)}")

# %%
# 4. Run Training Pipeline (Default: YOLOv11m)
# This will automatically download VisDrone and start training
# !python scripts/train_pipeline.py --model yolo11m.pt

# %%
# 5. (Optional) Train YOLOv11n (Nano) instead
# !python scripts/train_pipeline.py --model yolo11n.pt

# %%
# 6. (Optional) Run Smoke Test to verify setup (1 epoch, small image)
# !python scripts/train_pipeline.py --smoke-test --model yolo11n.pt

# %%
# 7. Zip and Download Results
# !zip -r runs.zip yolo11m_training_runs/
from google.colab import files
files.download('runs.zip')
